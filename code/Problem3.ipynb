# %%
words = []
vectors = []

with open("../word2vec/W2V_150.txt") as f:
    cnt = 0
    for line in f.readlines():
        if cnt <=1: 
            cnt+=1
            continue
        word, vector = line.split(" ", 1)
        words.append(word)
        vectors.append(vector)

print(f"length of words and vectors: {len(words)}, {len(vectors)}")
# Out:
# length of words and vectors: 77021, 77021

# %%
dict_word_2_vec = dict(zip((words), (vectors)))

# %%
def load_train_data(path: str) -> list:
    list_word_pair = [] 
    with open(path, 'r' , encoding = 'utf-8') as f: 
        for line in f: 
            word_pair = line[0: len(line) - 1].split(" ")
            list_word_pair.append([word_pair[0], word_pair[1]])
    return list_word_pair

# %%
antonyms_list = load_train_data("../antonym-synonym set/Antonym_vietnamese.txt")
synonyms_list = load_train_data("../antonym-synonym set/Synonym_vietnamese.txt")

# %%
antonyms_list
# Out:
# [['ác', 'hiền'],
#  ['ác', 'thiện'],
#  ['ác_cảm', 'thiện_cảm'],
#  ['ác_độc', 'hiền_lành'],
#  ['ác_độc', 'hiền_từ'],
#  ['ác_tính', 'lành_tính'],
#  ['ác_ý', 'thiện_ý'],
#  ['ám_muội', 'minh_bạch'],
#  ['an_tâm', 'lo_lắng'],
#  ['anh_dũng', 'hèn'],
#  ['anh_dũng', 'hèn_nhát'],
#  ['ăn_khách', 'ế'],
#  ['ẩm', 'khô'],
#  ['ẩm', 'khô_ráo'],
#  ['ẩm', 'ráo'],
#  ['ẩm_thấp', 'khô_ráo'],
#  ['ẩm_ướt', 'khô_ráo'],
#  ['ấm_áp', 'lạnh_lẽo'],
#  ['ẩn', 'hiện'],
#  ['bác', 'chấp_nhận'],
#  ['bác', 'chấp_thuận'],
#  ['bác_bỏ', 'chấp_nhận'],
#  ['bác_bỏ', 'chấp_thuận'],
#  ['bạc', 'hậu'],
#  ['bạc_đãi', 'trọng_đãi'],
#  ['bạc_màu', 'màu_mỡ'],
#  ['bạc_mầu', 'màu_mỡ'],
#  ['bãi_nhiệm', 'bổ_dụng'],
#  ['bãi_nhiệm', 'bổ_nhiệm'],
#  ['bại', 'thành'],
#  ['bại', 'thắng'],
#  ['bán', 'mua'],
#  ['bao_dung', 'hẹp_hòi'],
#  ['bao_vây', 'giải_vây'],
#  ['báo_ân', 'báo_oán'],
#  ['báo_ân', 'báo_thù'],
#  ['báo_ân', 'trả_thù'],
#  ['bần_tiện', 'hào_phóng'],
#  ['bẩn', 'sạch'],
#  ['bẩn', 'sạch_sẽ'],
#  ['bẩn_thỉu', 'sạch'],
#  ['bẩn_thỉu', 'sạch_sẽ'],
#  ['bận', 'rảnh'],
#  ['bận', 'rảnh_rang'],
#  ['bận', 'rảnh_rỗi'],
#  ['bận', 'rỗi'],
#  ['bận', 'rỗi_rãi'],
#  ['bế_giảng', 'khai_giảng'],
#  ['bế_mạc', 'khai_mạc'],
#  ['báo_đáp', 'báo_oán'],
#  ['báo_đáp', 'báo_thù'],
#  ['báo_đáp', 'trả_thù'],
#  ['báo_oán', 'báo_ơn'],
#  ['báo_ơn', 'báo_thù'],
#  ['báo_ơn', 'trả_thù'],
#  ['bạo', 'nhát'],
#  ['bạo_dạn', 'nhút_nhát'],
#  ['bay_bướm', 'chân_phương'],
#  ['bằng', 'gồ_ghề'],
#  ['bằng', 'lồi_lõm'],
#  ['bằng', 'mấp_mô'],
#  ['bằng_phẳng', 'gập_ghềnh'],
#  ['bằng_phẳng', 'lồi_lõm'],
#  ['bằng_phẳng', 'nhấp_nhô'],
#  ['bắt_đầu', 'kết_thúc'],
#  ['bận_bịu', 'rảnh_rang'],
#  ['bận_bịu', 'rảnh_rỗi'],
#  ['bận_bịu', 'rỗi_rãi'],
#  ['bận_bịu', 'thanh_nhàn'],
#  ['bận_bịu', 'thư_nhàn'],
#  ['bận_rộn', 'thanh_nhàn'],
#  ['bận_rộn', 'thư_nhàn'],
#  ['bất_đồng', 'thống_nhất'],
#  ['bất_hạnh', 'hạnh_phúc'],
#  ['bất_hiếu', 'có_hiếu'],
#  ['bất_kham', 'thuần'],
#  ['bất_lợi', 'thuận_lợi'],
#  ['bất_minh', 'minh_bạch'],
#  ['bất_nghĩa', 'có_nghĩa'],
#  ['bất_nhã', 'nhã_nhặn'],
#  ['bất_nhân', 'có_nhân'],
#  ['bất_nhân', 'nhân_ái'],
#  ['bất_thành_văn', 'thành_văn'],
#  ['bật', 'tắt'],
#  ['bé', 'lớn'],
#  ['bé', 'to'],
#  ['béo', 'gầy'],
#  ['bét', 'nhất'],
#  ['bi', 'hài'],
#  ['bi_quan', 'lạc_quan'],
#  ['bí_mật', 'công_khai'],
#  ['bị_động', 'chủ_động'],
#  ['biến_động', 'cố_định'],
#  ['biếng_nhác', 'chăm_chỉ'],
#  ['biếng_nhác', 'siêng_năng'],
#  ['biết_ơn', 'bội_ơn'],
#  ['biết_ơn', 'vô_ơn'],
#  ['biệt_li', 'đoàn_tụ'],
#  ['biệt_li', 'sum_họp'],
#  ['biệt_ly', 'đoàn_tụ'],
#  ['biệt_ly', 'sum_họp'],
#  ['bổng', 'trầm'],
#  ['bổng', 'la'],
#  ['bự', 'bé'],
#  ['bự', 'nhỏ'],
#  ['bừa', 'gọn'],
#  ['bừa_bãi', 'gọn_gàng'],
#  ['bừa_bãi', 'gọn_ghẽ'],
#  ['bổ_dụng', 'miễn_nhiệm'],
#  ['bổ_ích', 'vô_ích'],
#  ['bổ_nhậm', 'bãi_nhiệm'],
#  ['bổ_nhậm', 'miễn_nhiệm'],
#  ['bổ_nhiệm', 'miễn_nhiệm'],
#  ['bôi_đen', 'tô_hồng'],
#  ['bội_bạc', 'chung_thuỷ'],
#  ['bội_bạc', 'có_nghĩa'],
#  ['bội_bạc', 'thuỷ_chung'],
#  ['bội_chi', 'bội_thu'],
#  ['bội_nghĩa', 'biết_ơn'],
#  ['bội_nghĩa', 'hàm_ân'],
#  ['bội_nghĩa', 'hàm_ơn'],
#  ['bội_thu', 'thất_bát'],
#  ['bộp_chộp', 'chín_chắn'],
#  ['bở', 'dai'],
#  ['bớt', 'thêm'],
#  ['bụ', 'gầy'],
#  ['bụ', 'ngẳng'],
#  ['bủa_vây', 'giải_vây'],
#  ['bủn_xỉn', 'hào_phóng'],
#  ['buồn', 'mừng'],
#  ['buồn', 'vui'],
#  ['buồn_phiền', 'vui'],
#  ['buồn_phiền', 'vui_vẻ'],
#  ['can_đảm', 'hèn_nhát'],
#  ['cao', 'thấp'],
#  ['cao_kều', 'lùn_tè'],
#  ['cao_kều', 'lùn_tịt'],
#  ['cao_ngạo', 'khiêm_tốn'],
#  ['cao_quí', 'thấp_hèn'],
#  ['cao_quý', 'thấp_hèn'],
#  ['cao_sang', 'thấp_hèn'],
#  ['cao_trào', 'thoái_trào'],
#  ['cẩn_thận', 'ẩu'],
#  ['cẩn_thận', 'ẩu_tả'],
#  ['cẩn_thận', 'cẩu_thả'],
#  ['cấp_tiến', 'bảo_thủ'],
#  ['cấp_tính', 'mãn_tính'],
#  ['cấp_tính', 'mạn_tính'],
#  ['cất_cánh', 'hạ_cánh'],
#  ['cầu_kì', 'giản_dị'],
#  ['chao_đảo', 'kiên_định'],
#  ['chắc', 'kẹ'],
#  ['chắc', 'lép'],
#  ['chắc', 'óp'],
#  ['chắc_dạ', 'lo_lắng'],
#  ['chăm', 'lười'],
#  ['chăm', 'nhác'],
#  ['chăm_chỉ', 'chây_lười'],
#  ['chăm_chỉ', 'lười_biếng'],
#  ['chăm_chỉ', 'lười_nhác'],
#  ['chặt', 'lỏng'],
#  ['chặt', 'lỏng_lẻo'],
#  ['chặt_chẽ', 'lỏng_lẻo'],
#  ['chậm', 'nhanh'],
#  ['chậm', 'sớm'],
#  ['chân_thành', 'giả_dối'],
#  ['chân_thật', 'giả_dối'],
#  ['chân_thực', 'giả_dối'],
#  ['chần_chờ', 'dứt_khoát'],
#  ['chần_chừ', 'dứt_khoát'],
#  ['chấp_nhận', 'từ_chối'],
#  ['chấp_thuận', 'từ_chối'],
#  ['chật', 'rộng'],
#  ['chật_chội', 'rộng_rãi'],
#  ['chật_hẹp', 'rộng_rãi'],
#  ['chây_lười', 'siêng_năng'],
#  ['chê', 'khen'],
#  ['chê_bai', 'khen_ngợi'],
#  ['chết', 'sống'],
#  ['chi', 'thu'],
#  ['chín', 'xanh'],
#  ['chín', 'xanh_lè'],
#  ['chín', 'sống'],
#  ['có_lý', 'phi_lí'],
#  ['có_lý', 'vô_lí'],
#  ['có_mặt', 'vắng_mặt'],
#  ['có_nghĩa', 'vô_nghĩa'],
#  ['có_tình', 'vô_tình'],
#  ['coi_nhẹ', 'coi_trọng'],
#  ['coi_thường', 'chú_trọng'],
#  ['coi_thường', 'coi_trọng'],
#  ['coi_trọng', 'khinh_rẻ'],
#  ['cõi_dương', 'cõi_âm'],
#  ['cõi_trần', 'cõi_âm'],
#  ['cõi_tục', 'cõi_âm'],
#  ['chi_tiết', 'sơ_lược'],
#  ['chia_li', 'đoàn_tụ'],
#  ['chia_li', 'sum_họp'],
#  ['chia_ly', 'đoàn_tụ'],
#  ['chia_ly', 'sum_họp'],
#  ['chia_phôi', 'đoàn_tụ'],
#  ['chia_phôi', 'sum_họp'],
#  ['chia_rẽ', 'đoàn_kết'],
#  ['chia_tay', 'sum_họp'],
#  ['chia_tay', 'sum_vầy'],
#  ['chiến_bại', 'chiến_thắng'],
#  ['chiến_bại', 'thắng_lợi'],
#  ['chiến_thắng', 'thất_bại'],
#  ['chiến_tranh', 'hoà_bình'],
#  ['chìm', 'nổi'],
#  ['chính', 'phụ'],
#  ['chính', 'tà'],
#  ['chính_diện', 'phản_diện'],
#  ['chính_hiệu', 'giả_hiệu'],
#  ['chính_nghĩa', 'phi_nghĩa'],
#  ['chóng', 'chậm'],
#  ['chóng', 'lâu'],
#  ['chóng', 'muộn'],
#  ['chót', 'đầu'],
#  ['chối_từ', 'chấp_nhận'],
#  ['chơi_đẹp', 'chơi_xấu'],
#  ['chủ_động', 'thụ_động'],
#  ['chú_trọng', 'khinh_thường'],
#  ['chung_tình', 'bội_tình'],
#  ['chung_tình', 'phụ_bạc'],
#  ['chung_tình', 'phụ_tình'],
#  ['chùng', 'căng'],
#  ['có', 'khó'],
#  ['có', 'nghèo'],
#  ['có', 'không'],
#  ['có_học', 'vô_học'],
#  ['có_ích', 'vô_bổ'],
#  ['có_ích', 'vô_dụng'],
#  ['có_ích', 'vô_ích'],
#  ['có_lí', 'phi_lí'],
#  ['có_lí', 'vô_lí'],
#  ['cố_tình', 'vô_tình'],
#  ['cố_ý', 'vô_tình'],
#  ['còn', 'mất'],
#  ['còn', 'hết'],
#  ['cổ_hủ', 'tân_tiến'],
#  ['công', 'thủ'],
#  ['công_bằng', 'bất_công'],
#  ['công_nhận', 'phủ_nhận'],
#  ['cồng_kềnh', 'gọn_nhẹ'],
#  ['cũ', 'mới'],
#  ['cũ_kĩ', 'mới_cứng'],
#  ['cũ_kĩ', 'mới_mẻ'],
#  ['cũ_kĩ', 'mới_tinh'],
#  ['cũ_kỹ', 'mới_cứng'],
#  ['cũ_kỹ', 'mới_mẻ'],
#  ['cũ_kỹ', 'mới_tinh'],
#  ['cũ_mèm', 'mới_cứng'],
#  ['cũ_mèm', 'mới_mẻ'],
#  ['cũ_mèm', 'mới_tinh'],
#  ['cũ_rích', 'mới_cứng'],
#  ['cũ_rích', 'mới_mẻ'],
#  ['cũ_rích', 'mới_tinh'],
#  ['cùn', 'sắc'],
#  ['cuối', 'đầu'],
#  ['cuối_cùng', 'đầu_tiên'],
#  ['cực_khổ', 'sung_sướng'],
#  ['cứng', 'mềm'],
#  ['cứng_cỏi', 'mềm_yếu'],
#  ['cứng_nhắc', 'mềm'],
#  ['cứng_nhắc', 'mềm_dẻo'],
#  ['cứng_rắn', 'mềm_mỏng'],
#  ['cường_thịnh', 'suy_tàn'],
#  ['cường_thịnh', 'suy_vong'],
#  ['cưỡng_ép', 'tự_nguyện'],
#  ['cựu_binh', 'tân_binh'],
#  ['dài', 'ngắn'],
#  ['dài_dòng', 'ngắn_gọn'],
#  ['dài_thườn_thượt', 'ngắn_ngủn'],
#  ['dài_thượt', 'ngắn_ngủn'],
#  ['dại', 'khôn'],
#  ['dại_dột', 'khôn_ngoan'],
#  ['dạn_dĩ', 'nhát'],
#  ['dạn_dĩ', 'nhút_nhát'],
#  ['dao_động', 'kiên_định'],
#  ['dày', 'mỏng'],
#  ['dày', 'thưa'],
#  ['dày_cồm_cộp', 'mỏng_dính'],
#  ['dày_cồm_cộp', 'mỏng_rớt'],
#  ['dày_cồm_cộp', 'mỏng_tang'],
#  ['dày_cồm_cộp', 'mỏng_tanh'],
#  ['dày_cộp', 'mỏng_dính'],
#  ['dày_cộp', 'mỏng_rớt'],
#  ['dày_cộp', 'mỏng_tang'],
#  ['dày_cộp', 'mỏng_tanh'],
#  ['dày_đặc', 'loáng_thoáng'],
#  ['dày_đặc', 'thưa'],
#  ['dày_đặc', 'thưa_thớt'],
#  ['dầy_cồm_cộp', 'mỏng_dính'],
#  ['dầy_cồm_cộp', 'mỏng_rớt'],
#  ['dầy_cồm_cộp', 'mỏng_tang'],
#  ['dầy_cồm_cộp', 'mỏng_tanh'],
#  ['dầy_cộp', 'mỏng_dính'],
#  ['dầy_cộp', 'mỏng_rớt'],
#  ['dầy_cộp', 'mỏng_tang'],
#  ['dầy_cộp', 'mỏng_tanh'],
#  ['dầy_đặc', 'loáng_thoáng'],
#  ['dầy_đặc', 'thưa'],
#  ['dầy_đặc', 'thưa_thớt'],
#  ['dẻo', 'cứng'],
#  ['dễ', 'khó'],
#  ['dễ_chịu', 'khó_chịu'],
#  ['dễ_coi', 'khó_coi'],
#  ['dễ_dãi', 'khắt_khe'],
#  ['dễ_dàng', 'khó_khăn'],
#  ['dễ_tính', 'khó_tính'],
#  ['dễ_tính', 'khó_tính_khó_nết'],
#  ['di_cư', 'nhập_cư'],
#  ['dị_biệt', 'tương_đồng'],
#  ['do_dự', 'dứt_khoát'],
#  ['dọc', 'ngang'],
#  ['dối', 'kĩ'],
#  ['dối_trá', 'thật_thà'],
#  ['dông_dài', 'ngắn_gọn'],
#  ['dốt', 'thông_minh'],
#  ['dốt', 'giỏi'],
#  ['dơ_dáy', 'sạch'],
#  ['dơ_dáy', 'sạch_sẽ'],
#  ['dở', 'hay'],
#  ['dũng_cảm', 'hèn'],
#  ['dũng_cảm', 'hèn_nhát'],
#  ['dút_dát', 'bạo_dạn'],
#  ['dư_dả', 'thiếu_thốn'],
#  ['dư_dật', 'thiếu_thốn'],
#  ['dư_thừa', 'thiếu_thốn'],
#  ['dữ', 'hiền'],
#  ['dữ', 'thiện'],
#  ['dữ', 'lành'],
#  ['dự_bị', 'chính_thức'],
#  ['dưới', 'trên'],
#  ['dương_gian', 'âm_phủ'],
#  ['dương_gian', 'cõi_âm'],
#  ['đại', 'tiểu'],
#  ['đại_bại', 'đại_thắng'],
#  ['đại_lượng', 'hẹp_hòi'],
#  ['đóng', 'mở'],
#  ['đóng_cửa', 'mở_cửa'],
#  ['đãng_trí', 'chăm_chú'],
#  ['đãng_trí', 'chú_ý'],
#  ['đặc', 'loãng'],
#  ['đặc', 'rỗng'],
#  ['đắn_đo', 'dứt_khoát'],
#  ['đắt', 'rẻ'],
#  ['đắt', 'ế'],
#  ['đắt_đỏ', 'rẻ_mạt'],
#  ['đậm', 'nhạt'],
#  ['đần', 'thông_minh'],
#  ['đần_độn', 'thông_minh'],
#  ['đầy', 'vơi'],
#  ['đầy_đủ', 'sơ_sài'],
#  ['đầy_đủ', 'thiếu_thốn'],
#  ['đen', 'trắng'],
#  ['đen', 'đỏ'],
#  ['đen_đủi', 'may_mắn'],
#  ['đen_sì', 'trắng_tinh'],
#  ['đen_tối', 'minh_bạch'],
#  ['đẹp', 'xấu'],
#  ['đê_hèn', 'cao_thượng'],
#  ['đê_tiện', 'cao_thượng'],
#  ['địch', 'ta'],
#  ['định_kì', 'bất_thường'],
#  ['định_kỳ', 'bất_thường'],
#  ['đoàn_tụ', 'li_tán'],
#  ['đói', 'no'],
#  ['đón', 'tiễn'],
#  ['độ_lượng', 'hẹp_hòi'],
#  ['độc', 'lành'],
#  ['độc_ác', 'hiền_lành'],
#  ['độc_ác', 'hiền_từ'],
#  ['đông', 'thưa'],
#  ['đông', 'vắng'],
#  ['đông_đúc', 'quạnh_vắng'],
#  ['đông_đúc', 'vắng_vẻ'],
#  ['đồng_tình', 'phản_đối'],
#  ['đồng_ý', 'phản_đối'],
#  ['đồng_ý', 'từ_chối'],
#  ['động', 'tĩnh'],
#  ['đơn', 'đôi'],
#  ['đơn', 'kép'],
#  ['đơn_giản', 'phức_tạp'],
#  ['đơn_giản', 'rắc_rối'],
#  ['đục', 'trong'],
#  ['đúng', 'sai'],
#  ['đúng_đắn', 'lệch_lạc'],
#  ['đúng_đắn', 'méo_mó'],
#  ['đúng_đắn', 'sai_lầm'],
#  ['đúng_đắn', 'sai_trái'],
#  ['đuối', 'tươi'],
#  ['được', 'mất'],
#  ['được', 'thua'],
#  ['được_lòng', 'mất_lòng'],
#  ['được_lòng', 'mếch_lòng'],
#  ['được_mùa', 'mất_mùa'],
#  ['được_mùa', 'thất_bát'],
#  ['ép_buộc', 'tự_nguyện'],
#  ['gan_dạ', 'hèn_nhát'],
#  ['gần', 'xa'],
#  ['gầy', 'mập'],
#  ['ghét', 'yêu'],
#  ['già', 'trẻ'],
#  ['già', 'non'],
#  ['già_câng', 'non_choẹt'],
#  ['già_dặn', 'non_nớt'],
#  ['giả_dối', 'thật_thà'],
#  ['giải_tán', 'tập_hợp'],
#  ['giải_tán', 'tập_trung'],
#  ['giải_tán', 'tụ_tập'],
#  ['giải_toả', 'bao_vây'],
#  ['giải_toả', 'phong_toả'],
#  ['giải_vây', 'phong_bế'],
#  ['giải_vây', 'phong_toả'],
#  ['giam_hãm', 'giam_giữ'],
#  ['giảm', 'tăng'],
#  ['gian', 'ngay'],
#  ['gian_giảo', 'thật_thà'],
#  ['gian_trá', 'thật_thà'],
#  ['gian_xảo', 'thật_thà'],
#  ['giản_đơn', 'phức_tạp'],
#  ['giản_đơn', 'rắc_rối'],
#  ['gián_tiếp', 'trực_tiếp'],
#  ['giáng_hạ', 'thăng_thiên'],
#  ['giảo_hoạt', 'thật_thà'],
#  ['giảo_quyệt', 'thật_thà'],
#  ['giàu', 'khó'],
#  ['giàu', 'nghèo'],
#  ['giàu', 'ít'],
#  ['giàu_có', 'nghèo_khó'],
#  ['giàu_có', 'nghèo_khổ'],
#  ['giàu_có', 'nghèo_nàn'],
#  ['giàu_sang', 'nghèo_hèn'],
#  ['giầu', 'khó'],
#  ['giầu', 'nghèo'],
#  ['giầu_có', 'nghèo_khó'],
#  ['giầu_có', 'nghèo_khổ'],
#  ['giầu_có', 'nghèo_nàn'],
#  ['giầu_sang', 'nghèo_hèn'],
#  ['gin', 'rởm'],
#  ['giỏi', 'kém'],
#  ['giỏi', 'tồi'],
#  ['giỏi_giang', 'kém_cỏi'],
#  ['giống', 'khác'],
#  ['gọn', 'bừa_bãi'],
#  ['gọn', 'bừa_bộn'],
#  ['gọn_gàng', 'bừa_bộn'],
#  ['gọn_ghẽ', 'bừa_bộn'],
#  ['gọn_nhẹ', 'rườm_rà'],
#  ['gồ_ghề', 'bằng_phẳng'],
#  ['hà_tiện', 'hoang'],
#  ['hà_tiện', 'hoang_phí'],
#  ['hà_tiện', 'hoang_toàng'],
#  ['hạ', 'tăng'],
#  ['hạ_đẳng', 'thượng_đẳng'],
#  ['hạ_màn', 'mở_màn'],
#  ['hải_quan', 'sửa_lỗi_chính_tả_ở_ĐN'],
#  ['hại', 'lợi'],
#  ['hàn', 'nhiệt'],
#  ['hạn_hán', 'lụt_lội'],
#  ['hào_phóng', 'ki_bo'],
#  ['hôi_rình', 'thơm_tho'],
#  ['hèn', 'can_đảm'],
#  ['hèn', 'sang'],
#  ['héo', 'tươi'],
#  ['hẹp', 'rộng'],
#  ['hẹp_hòi', 'rộng_lượng'],
#  ['hên', 'xui'],
#  ['hi_vọng', 'thất_vọng'],
#  ['hi_vọng', 'vô_vọng'],
#  ['hiếu_thảo', 'bất_hiếu'],
#  ['hoà_thuận', 'lủng_củng'],
#  ['hoạ', 'phúc'],
#  ['hoang', 'tằn_tiện'],
#  ['hoang_phí', 'tằn_tiện'],
#  ['hoang_toàng', 'tằn_tiện'],
#  ['hỏi', 'đáp'],
#  ['hỏi', 'trả_lời'],
#  ['hở', 'kín'],
#  ['hời_hợt', 'sâu_sắc'],
#  ['hơn', 'kém'],
#  ['hơn', 'thua'],
#  ['hơn', 'thiệt'],
#  ['hợp_lí', 'phi_lí'],
#  ['hợp_lí', 'vô_lí'],
#  ['hợp_lý', 'phi_lí'],
#  ['hợp_lý', 'vô_lí'],
#  ['hợp_pháp', 'phi_pháp'],
#  ['hư', 'ngoan'],
#  ['hư', 'thực'],
#  ['hưng_thịnh', 'suy_tàn'],
#  ['hưng_thịnh', 'suy_vong'],
#  ['hướng_tâm', 'li_tâm'],
#  ['hữu_hạn', 'vô_hạn'],
#  ['hữu_hiệu', 'vô_hiệu'],
#  ['hữu_hình', 'vô_hình'],
#  ['hữu_ích', 'vô_bổ'],
#  ['hữu_ích', 'vô_dụng'],
#  ['hữu_ích', 'vô_tích_sự'],
#  ['hữu_ích', 'vô_ích'],
#  ['hữu_sinh', 'vô_sinh'],
#  ['hữu_tình', 'vô_tình'],
#  ['hữu_ý', 'vô_tình'],
#  ['hy_vọng', 'thất_vọng'],
#  ['hy_vọng', 'vô_vọng'],
#  ['ích', 'vô_ích'],
#  ['ích_kỉ', 'vị_tha'],
#  ['ích_kỷ', 'vị_tha'],
#  ['ỉu', 'giòn'],
#  ['kẹ', 'mẩy'],
#  ['keo_kiệt', 'hào_phóng'],
#  ['kết_nạp', 'khai_trừ'],
#  ['kết_thúc', 'khởi_đầu'],
#  ['kết_thúc', 'mở_đầu'],
#  ['khác_biệt', 'tương_đồng'],
#  ['khẳng_định', 'phủ_định'],
#  ['khấp_khểnh', 'bằng_phẳng'],
#  ['khéo', 'vụng'],
#  ['khéo_léo', 'vụng_về'],
#  ['khiêm_tốn', 'kiêu'],
#  ['khiêm_tốn', 'kiêu_căng'],
#  ['khiêm_tốn', 'kiêu_ngạo'],
#  ['khiếm_nhã', 'nhã_nhặn'],
#  ['khinh', 'trọng'],
#  ['khinh_nhờn', 'kính_nể'],
#  ['khinh_nhờn', 'kính_trọng'],
#  ['khinh_thường', 'coi_trọng'],
#  ['khoan', 'mau'],
#  ['khoan', 'nhặt'],
#  ['khoan_dung', 'hẹp_hòi'],
#  ['khoẻ', 'yếu'],
#  ['khô', 'ướt'],
#  ['khô_cằn', 'màu_mỡ'],
#  ['khô_khan', 'ướt_át'],
#  ['khô_ráo', 'ướt_át'],
#  ['khổ', 'sướng'],
#  ['khổ_sở', 'sung_sướng'],
#  ['khôn', 'khờ'],
#  ['khôn_khéo', 'vụng_dại'],
#  ['khổng_lồ', 'tí_hon'],
#  ['khuất_tất', 'minh_bạch'],
#  ['khuyết', 'ưu'],
#  ['khuyết_điểm', 'ưu_điểm'],
#  ['khước_từ', 'chấp_nhận'],
#  ['kĩ', 'qua_loa'],
#  ['kĩ', 'qua_quýt'],
#  ['kĩ', 'sơ_sài'],
#  ['kĩ_càng', 'dối'],
#  ['kĩ_càng', 'qua_loa'],
#  ['kĩ_càng', 'qua_quýt'],
#  ['kĩ_càng', 'sơ_sài'],
#  ['kĩ_lưỡng', 'dối'],
#  ['kĩ_lưỡng', 'qua_loa'],
#  ['kĩ_lưỡng', 'qua_quýt'],
#  ['kĩ_lưỡng', 'sơ_sài'],
#  ['kiên_định', 'ngả_nghiêng'],
#  ['kìm_hãm', 'thúc_đẩy'],
#  ['kỹ', 'dối'],
#  ['kỹ', 'qua_loa'],
#  ['kỹ', 'qua_quýt'],
#  ['kỹ', 'sơ_sài'],
#  ['kỹ_lưỡng', 'dối'],
#  ['kỹ_lưỡng', 'qua_loa'],
#  ['kỹ_lưỡng', 'qua_quýt'],
#  ['kỹ_lưỡng', 'sơ_sài'],
#  ['lạ', 'quen'],
#  ['lạc_hậu', 'tiên_tiến'],
#  ['lai', 'thuần_chủng'],
#  ['lãi', 'lỗ'],
#  ['lãng_phí', 'tiết_kiệm'],
#  ['lanh', 'chậm'],
#  ['lành_lặn', 'què_quặt'],
#  ['lành_lặn', 'rách_rưới'],
#  ['lạnh', 'nóng'],
#  ['lạnh_lẽo', 'ấm_cúng'],
#  ['lạt_lẽo', 'mặn_mà'],
#  ['lạt_lẽo', 'mặn_mòi'],
#  ['láu_táu', 'chín_chắn'],
#  ['lắm', 'ít'],
#  ['lặn', 'mọc'],
#  ['lần_chần', 'dứt_khoát'],
#  ['lần_khần', 'dứt_khoát'],
#  ['lâu', 'mau'],
#  ['lè', 'rụt'],
#  ['lè', 'thụt'],
#  ['lẹ', 'chậm'],
#  ['lẹ', 'lâu'],
#  ['lép', 'mẩy'],
#  ['lệch', 'ngay'],
#  ['lệch', 'thẳng'],
#  ['lệch', 'cân'],
#  ['lệch', 'cân_đối'],
#  ['lên', 'xuống'],
#  ['lên_nước', 'xuống_nước'],
#  ['li_biệt', 'đoàn_tụ'],
#  ['li_biệt', 'sum_họp'],
#  ['lõm', 'lồi'],
#  ['lỗ', 'lời'],
#  ['lộn_xộn', 'gọn_gàng'],
#  ['lộn_xộn', 'gọn_ghẽ'],
#  ['lời_lãi', 'thua_lỗ'],
#  ['lợi', 'thiệt'],
#  ['lớn', 'nhỏ'],
#  ['lu', 'tỏ'],
#  ['lùn', 'cao'],
#  ['lung_tung', 'gọn_gàng'],
#  ['lung_tung', 'gọn_ghẽ'],
#  ['lủng_củng', 'thuận_hoà'],
#  ['lười', 'siêng'],
#  ['lười_biếng', 'siêng_năng'],
#  ['lương_thiện', 'bất_lương'],
#  ['lương_thiện', 'vô_lương'],
#  ['lưỡng_lự', 'dứt_khoát'],
#  ['lưu_thông', 'ách_tắc'],
#  ['lưu_thông', 'tắc_nghẽn'],
#  ['ly_biệt', 'đoàn_tụ'],
#  ['ly_biệt', 'sum_họp'],
#  ['ly_tán', 'đoàn_tụ'],
#  ['ly_tâm', 'hướng_tâm'],
#  ['man_trá', 'thật_thà'],
#  ['mạnh', 'yếu'],
#  ['mạnh_bạo', 'nhút_nhát'],
#  ['mạnh_dạn', 'nhát'],
#  ['mạnh_dạn', 'nhút_nhát'],
#  ['mạnh_mẽ', 'yếu_ớt'],
#  ['mát', 'tươi'],
#  ['mát_mẻ', 'nóng_bức'],
#  ['mát_mẻ', 'nóng_nực'],
#  ['mát_mẻ', 'oi_bức'],
#  ['mát_tính', 'nóng_tính'],
#  ['mau', 'chậm'],
#  ['mau', 'thưa'],
#  ['may', 'rủi'],
#  ['may_mắn', 'rủi_ro'],
#  ['may_mắn', 'xui_xẻo'],
#  ['mặn', 'nhạt'],
#  ['mặn_mà', 'nhạt_nhẽo'],
#  ['mấp_mô', 'bằng_phẳng'],
#  ['mập', 'ngẳng'],
#  ['mầu_mỡ', 'bạc_màu'],
#  ['mầu_mỡ', 'khô_cằn'],
#  ['mẩy', 'óp'],
#  ['méo', 'tròn'],
#  ['mịn', 'ráp'],
#  ['mịn_màng', 'thô_ráp'],
#  ['minh_bạch', 'mờ_ám'],
#  ['mong', 'thất_vọng'],
#  ['mong', 'vô_vọng'],
#  ['mờ', 'tỏ'],
#  ['mở', 'tắt'],
#  ['mở_rộng', 'thu_hẹp'],
#  ['muộn', 'sớm'],
#  ['muộn_màng', 'sớm_sủa'],
#  ['nản_chí', 'kiên_định'],
#  ['nản_lòng', 'kiên_định'],
#  ['nao_núng', 'kiên_định'],
#  ['náu', 'hiện'],
#  ['nặng', 'nhẹ'],
#  ['nặng_kí', 'nhẹ_kí'],
#  ['nặng_ký', 'nhẹ_kí'],
#  ['nặng_nề', 'nhẹ_nhàng'],
#  ['nặng_nhọc', 'nhẹ_nhàng'],
#  ['nặng_trịch', 'nhẹ_bỗng'],
#  ['nặng_trịch', 'nhẹ_tênh'],
#  ['nấp', 'hiện'],
#  ['ngậm', 'há'],
#  ['ngay_ngắn', 'lệch_lạc'],
#  ['ngay_ngắn', 'xiên_xẹo'],
#  ['ngày', 'đêm'],
#  ['ngăn_nắp', 'lộn_xộn'],
#  ['ngăn_nắp', 'lung_tung'],
#  ['ngăn_nắp', 'luộm_thuộm'],
#  ['ngầm', 'lộ_thiên'],
#  ['ngần_ngừ', 'dứt_khoát'],
#  ['nghèo_nàn', 'phong_phú'],
#  ['ngoài', 'trong'],
#  ['ngoại_lệ', 'thường_lệ'],
#  ['ngờ', 'tin'],
#  ['ngu', 'khôn'],
#  ['ngu_đần', 'thông_minh'],
#  ['ngửa', 'sấp'],
#  ['ngược', 'thuận'],
#  ['ngược', 'xuôi'],
#  ['nhám', 'mịn'],
#  ['nhanh', 'lâu'],
#  ['nhạt', 'sẫm'],
#  ['nhạt', 'sậm'],
#  ['nhạt', 'thẫm'],
#  ['nhạt_nhẽo', 'mặn_mòi'],
#  ['nhạt_phèo', 'mặn_mà'],
#  ['nhạt_phèo', 'mặn_mòi'],
#  ['nhạt_thếch', 'mặn_mà'],
#  ['nhạt_thếch', 'mặn_mòi'],
#  ['nhẵn', 'sần_sùi'],
#  ['nhẵn', 'xù_xì'],
#  ['nhẵn_nhụi', 'sần_sùi'],
#  ['nhẵn_nhụi', 'xù_xì'],
#  ['nhặt', 'thưa'],
#  ['nhân_đức', 'thất_đức'],
#  ['nhập', 'tách'],
#  ['nhẹ', 'mạnh'],
#  ['nhẹ_nhõm', 'nặng_nề'],
#  ['nhẽo', 'săn'],
#  ['nhiều', 'ít'],
#  ['nhỏ', 'to'],
#  ['nhỏ_con', 'to_con'],
#  ['nhỏ_xíu', 'to_tướng'],
#  ['nhộn_nhịp', 'vắng_ngắt'],
#  ['nhốt', 'thả'],
#  ['nhớ', 'quên'],
#  ['nhợt_nhạt', 'tươi_tắn'],
#  ['nhu', 'cương'],
#  ['nhục', 'vinh'],
#  ['nhược_điểm', 'ưu_điểm'],
#  ['non_choẹt', 'già_cấc'],
#  ['nóng_nảy', 'mát_tính'],
#  ['nóng_nẩy', 'mát_tính'],
#  ['nông', 'sâu'],
#  ['nông_cạn', 'sâu_sắc'],
#  ['nông_nổi', 'chín_chắn'],
#  ['nờm_nợp', 'vắng_ngắt'],
#  ['núp', 'hiện'],
#  ['nườm_nượp', 'vắng_ngắt'],
#  ['phân_ly', 'đoàn_tụ'],
#  ['phân_ly', 'sum_họp'],
#  ['phung_phí', 'tiết_kiệm'],
#  ['phản_đối', 'ủng_hộ'],
#  ['phát_triển', 'suy_thoái'],
#  ['phân_li', 'đoàn_tụ'],
#  ['phân_li', 'sum_họp'],
#  ['phân_tích', 'tổng_hợp'],
#  ['phân_vân', 'dứt_khoát'],
#  ['phi_lí', 'hữu_lí'],
#  ['phi_lý', 'có_lí'],
#  ['phi_lý', 'hợp_lí'],
#  ['phi_lý', 'hữu_lí'],
#  ['phì_nhiêu', 'bạc_màu'],
#  ['phì_nhiêu', 'khô_cằn'],
#  ['phiến_diện', 'toàn_diện'],
#  ['phổ_biến', 'cá_biệt'],
#  ['phủ_nhận', 'xác_nhận'],
#  ['phụ_thuộc', 'độc_lập'],
#  ['phúc_đức', 'ác_đức'],
#  ['phước', 'hoạ'],
#  ['sít', 'thưa'],
#  ['quỉ_quyệt', 'thật_thà'],
#  ['quỷ_quyệt', 'thật_thà'],
#  ['rách', 'lành'],
#  ['rảnh', 'bận_bịu'],
#  ['rắn', 'mềm'],
#  ['rét', 'ấm'],
#  ['rỗi', 'bận_bịu'],
#  ['rộn_rịch', 'vắng_ngắt'],
#  ['rút_rát', 'bạo_dạn'],
#  ['rụt', 'thè'],
#  ['rụt', 'thò'],
#  ['sang_giàu', 'nghèo_hèn'],
#  ['sáng', 'tối'],
#  ['sáng_dạ', 'tối_dạ'],
#  ['sáng_sủa', 'tăm_tối'],
#  ['sáng_sủa', 'tối_tăm'],
#  ['sáng_suốt', 'u_mê'],
#  ['sau', 'trước'],
#  ['say', 'tỉnh'],
#  ['sẵn', 'hiếm'],
#  ['sần', 'nhẵn'],
#  ['sần', 'nhẵn_nhụi'],
#  ['sâu', 'cạn'],
#  ['siêng', 'biếng'],
#  ['siêng', 'nhác'],
#  ['siêng_năng', 'lười_nhác'],
#  ['sơ_lược', 'kĩ_càng'],
#  ['sơ_lược', 'kĩ_lưỡng'],
#  ['sơ_sài', 'chi_tiết'],
#  ['sờn', 'kiên_định'],
#  ['sờn_lòng', 'kiên_định'],
#  ['sung_sướng', 'khổ_cực'],
#  ['suy', 'thịnh'],
#  ['tài', 'kém'],
#  ['tài_ba', 'kém_cỏi'],
#  ['tán_thành', 'phản_đối'],
#  ['tắc', 'thông'],
#  ['tắc_nghẽn', 'thông_suốt'],
#  ['tấn_tới', 'thụt_lùi'],
#  ['tấp_nập', 'vắng_ngắt'],
#  ['thân', 'dưng'],
#  ['thân', 'sơ'],
#  ['thơ_thới', 'lo_âu'],
#  ['thơ_thới', 'ưu_tư'],
#  ['thanh_nhàn', 'vất_vả'],
#  ['thanh_thản', 'lo_âu'],
#  ['thanh_thản', 'ưu_tư'],
#  ['thanh_thoát', 'lo_âu'],
#  ['thanh_thoát', 'ưu_tư'],
#  ['thành_công', 'thất_bại'],
#  ['thảnh_thơi', 'lo_âu'],
#  ['thảnh_thơi', 'ưu_tư'],
#  ['thảo', 'tham'],
#  ['thảo', 'tham_lam'],
#  ['thẳng', 'cong'],
#  ['thẳng', 'vẹo'],
#  ['thắng', 'thua'],
#  ['thắng_lợi', 'thất_bại'],
#  ['thắt', 'mở'],
#  ['thất_cử', 'đắc_cử'],
#  ['thất_thu', 'bội_thu'],
#  ['thâu', 'chi'],
#  ['thè', 'thụt'],
#  ['thiện_chí', 'ác_ý'],
#  ['thiệt_thà', 'gian_giảo'],
#  ['thiếu_thốn', 'thừa_thãi'],
#  ['thịnh_vượng', 'sa_sút'],
#  ['thịnh_vượng', 'lụn_bại'],
#  ['thò', 'thụt'],
#  ['thoái', 'tiến'],
#  ['thoái_chí', 'kiên_định'],
#  ['thoáng', 'bí'],
#  ['thong_dong', 'vội_vã'],
#  ['thong_thả', 'vội'],
#  ['thong_thả', 'vội_vã'],
#  ['thong_thả', 'vội_vàng'],
#  ['thối', 'tiến'],
#  ['thối_chí', 'kiên_định'],
#  ['thông_minh', 'ngu_dốt'],
#  ['thông_minh', 'tối_dạ'],
#  ['thông_minh', 'ngu_ngốc'],
#  ['thời_bình', 'thời_chiến'],
#  ['thủ_cựu', 'tân_tiến'],
#  ['thuận', 'nghịch'],
#  ['thụt_lùi', 'tiến_bộ'],
#  ['thư_thái', 'lo_âu'],
#  ['thư_thái', 'ưu_tư'],
#  ['thưa_thớt', 'um_tùm'],
#  ['thừa_nhận', 'phủ_nhận'],
#  ['thực_thà', 'gian_giảo'],
#  ['thường', 'lạ_thường'],
#  ['thường', 'khác_thường'],
#  ['thường_kì', 'bất_thường'],
#  ['thường_kỳ', 'bất_thường'],
#  ['tỉ_mỉ', 'dối'],
#  ['tỉ_mỉ', 'qua_loa'],
#  ['tỉ_mỉ', 'qua_quýt'],
#  ['tỉ_mỉ', 'sơ_sài'],
#  ['tích_cực', 'tiêu_cực'],
#  ['tiến', 'lui'],
#  ['tiến', 'lùi'],
#  ['tiện', 'bất_tiện'],
#  ['tỉnh_táo', 'mê_muội'],
#  ['tồi', 'tốt'],
#  ['tối_đa', 'tối_thiểu'],
#  ['tốt', 'xấu'],
#  ['tốt_bụng', 'xấu_bụng'],
#  ['tốt_đẹp', 'xấu_xa'],
#  ['tốt_số', 'xấu_số'],
#  ['tốt_tính', 'xấu_tính'],
#  ['tợn', 'hiền'],
#  ['tợn', 'thiện'],
#  ['trắng', 'màu'],
#  ['trắng_trẻo', 'đen_đủi'],
#  ['trần_gian', 'cõi_âm'],
#  ['trần_thế', 'cõi_âm'],
#  ['trọng', 'coi_thường'],
#  ['trốn', 'hiện'],
#  ['trù_trừ', 'dứt_khoát'],
#  ['tự_cao', 'khiêm_tốn'],
#  ['tự_phụ', 'khiêm_nhường'],
#  ['tự_phụ', 'khiêm_tốn'],
#  ['tươi_sáng', 'u_ám'],
#  ['tỷ_mỉ', 'dối'],
#  ['tỷ_mỉ', 'qua_loa'],
#  ['tỷ_mỉ', 'qua_quýt'],
#  ['tỷ_mỉ', 'sơ_sài'],
#  ['u_buồn', 'tươi_vui'],
#  ['u_buồn', 'vui_tươi'],
#  ['ướt', 'ráo'],
#  ['ưu', 'khuyết_điểm'],
#  ['vượng', 'suy'],
#  ['vào', 'ra'],
#  ['vắng_lặng', 'ồn_ào'],
#  ['vắng_tanh', 'nhộn_nhịp'],
#  ['vắng_tanh', 'tấp_nập'],
#  ['vắng_teo', 'nhộn_nhịp'],
#  ['vắng_teo', 'tấp_nập'],
#  ['vị_kỉ', 'vị_tha'],
#  ['vị_kỷ', 'vị_tha'],
#  ['vong_ân', 'hàm_ân'],
#  ['vong_ân', 'hàm_ơn'],
#  ['vô', 'ra'],
#  ['vô_bổ', 'bổ_ích'],
#  ['vô_bổ', 'hữu_dụng'],
#  ['vô_dụng', 'hữu_dụng'],
#  ['vô_giá', 'vô_giá_trị'],
#  ['vô_ích', 'hữu_dụng'],
#  ['vô_lí', 'hữu_lí'],
#  ['vô_lý', 'có_lí'],
#  ['vô_lý', 'hợp_lí'],
#  ['vô_lý', 'hữu_lí'],
#  ['vô_song', 'vô_địch'],
#  ['vồ_vập', 'thờ_ơ'],
#  ['vỡ', 'lành'],
#  ['vui_tươi', 'u_sầu'],
#  ['xảo_quyệt', 'thật_thà'],
#  ['xảo_trá', 'thật_thà'],
#  ['xấu', 'xinh'],
#  ['xịn', 'rởm'],
#  ['xúi_quẩy', 'may_mắn'],
#  ['yên_lòng', 'lo_lắng'],
#  ['yên_ổn', 'bất_ổn'],
#  ['yên_tâm', 'lo_lắng'],
#  ['yếu_đuối', 'mạnh_mẽ'],
#  ['ác', 'thiện'],
#  ['ác_độc', 'hiền_lành'],
#  ['ác_tính', 'lành_tính'],
#  ['ám_muội', 'minh_bạch'],
#  ['anh_dũng', 'hèn'],
#  ['ăn_khách', 'ế'],
#  ['bác', 'chấp_nhận'],
#  ['bác_bỏ', 'chấp_nhận'],
#  ['bạc', 'hậu'],
#  ['bạc_màu', 'màu_mỡ'],
#  ['bại', 'thành'],
#  ['bán', 'mua'],
#  ['bao_vây', 'giải_vây'],
#  ['báo_ân', 'báo_thù'],
#  ['bế_giảng', 'khai_giảng'],
#  ['báo_đáp', 'báo_oán'],
#  ['báo_đáp', 'trả_thù'],
#  ['báo_ơn', 'báo_thù'],
#  ['bạo', 'nhát'],
#  ['bay_bướm', 'chân_phương'],
#  ['bé', 'to'],
#  ['bét', 'nhất'],
#  ['bi_quan', 'lạc_quan'],
#  ['bị_động', 'chủ_động'],
#  ['biếng_nhác', 'chăm_chỉ'],
#  ['biết_ơn', 'bội_ơn'],
#  ['biệt_li', 'đoàn_tụ'],
#  ['biệt_ly', 'đoàn_tụ'],
#  ['bổng', 'trầm'],
#  ['bừa', 'gọn'],
#  ['bừa_bãi', 'gọn_ghẽ'],
#  ['bổ_ích', 'vô_ích'],
#  ['bổ_nhậm', 'miễn_nhiệm'],
#  ['bôi_đen', 'tô_hồng'],
#  ['bở', 'dai'],
#  ['bụ', 'gầy'],
#  ['bủa_vây', 'giải_vây'],
#  ['buồn', 'mừng'],
#  ['buồn_phiền', 'vui'],
#  ['can_đảm', 'hèn_nhát'],
#  ['cao_kều', 'lùn_tè'],
#  ['cao_ngạo', 'khiêm_tốn'],
#  ['cao_quý', 'thấp_hèn'],
#  ['cao_trào', 'thoái_trào'],
#  ['chắc', 'kẹ'],
#  ['chắc', 'óp'],
#  ['chăm', 'lười'],
#  ['chăm_chỉ', 'chây_lười'],
#  ['chăm_chỉ', 'lười_nhác'],
#  ['chặt', 'lỏng_lẻo'],
#  ['chậm', 'nhanh'],
#  ['chân_thành', 'giả_dối'],
#  ['chân_thực', 'giả_dối'],
#  ['chần_chừ', 'dứt_khoát'],
#  ['chấp_thuận', 'từ_chối'],
#  ['chật_chội', 'rộng_rãi'],
#  ['chây_lười', 'siêng_năng'],
#  ['chê_bai', 'khen_ngợi'],
#  ['chi', 'thu'],
#  ['chín', 'xanh_lè'],
#  ['có_lý', 'phi_lí'],
#  ['có_mặt', 'vắng_mặt'],
#  ['có_tình', 'vô_tình'],
#  ['coi_thường', 'chú_trọng'],
#  ['coi_trọng', 'khinh_rẻ'],
#  ['chi_tiết', 'sơ_lược'],
#  ['chia_li', 'sum_họp'],
#  ['chia_ly', 'sum_họp'],
#  ['chia_phôi', 'sum_họp'],
#  ['chia_tay', 'sum_họp'],
#  ['chiến_bại', 'chiến_thắng'],
#  ['chiến_thắng', 'thất_bại'],
#  ['chìm', 'nổi'],
#  ['chính', 'tà'],
#  ['chính_hiệu', 'giả_hiệu'],
#  ['chóng', 'chậm'],
#  ['chóng', 'muộn'],
#  ['chối_từ', 'chấp_nhận'],
#  ['chủ_động', 'thụ_động'],
#  ['chung_tình', 'bội_tình'],
#  ['chung_tình', 'phụ_tình'],
#  ['có', 'khó'],
#  ['có', 'không'],
#  ['có_ích', 'vô_bổ'],
#  ['có_ích', 'vô_ích'],
#  ['có_lí', 'vô_lí'],
#  ['cố_ý', 'vô_tình'],
#  ['công', 'thủ'],
#  ...]

# %%
def get_vec_from_word(word):
    if dict_word_2_vec.get(word) is None:
        return None
    res = (dict_word_2_vec.get(word).split())
    return [float(l) for l in res ]

# %%
def get_feature_of_pair_word(word1, word2):
    vector1 = get_vec_from_word(word1)
    vector2 = get_vec_from_word(word2)

    if vector1 is not None and vector2 is not None:
        return vector1 + vector2
    else:
        return None

# %%
def generate_train_data():
    x_train = []
    y_train = []

    for word_pair in synonyms_list:
        feature = get_feature_of_pair_word(word_pair[0], word_pair[1])
        if feature is not None:
            y_train.extend([1])
            x_train.append(feature)

    for word_pair in antonyms_list:
        feature = get_feature_of_pair_word(word_pair[0], word_pair[1])
        if feature is not None:
            y_train.extend([0])
            x_train.append(feature)
    
    return x_train, y_train

# %%
def generate_test_data(path):
    x_test = []
    y_test = []
    word_pair_list= []

    with open(path, 'r', encoding='utf-8') as f:
        for line in f:
            splited = line[0:-1].split("\t")
            word_pair_list.append([splited[0], splited[1], splited[2]])

    for word_pair in word_pair_list:
        feature = get_feature_of_pair_word(word_pair[0], word_pair[1])
        if feature is not None:
            y_test.extend([1] if word_pair[2] == "SYN" else [0])
            x_test.append(feature)

    return x_test, y_test

# %%
x_train, y_train = generate_train_data()

# %%
from sklearn.linear_model import LogisticRegression
classifier_model = LogisticRegression()

classifier_model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import classification_report

# %%
x_test, y_test = generate_test_data("../datasets/ViCon-400/600_adj_pairs.txt")
y_pred = classifier_model.predict(x_test)

print(classification_report(y_test, y_pred, target_names=['0','1']))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.66      0.74       282
#            1       0.67      0.85      0.75       227
#
#     accuracy                           0.74       509
#    macro avg       0.76      0.75      0.74       509
# weighted avg       0.76      0.74      0.74       509
